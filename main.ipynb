# %% [markdown]
# # Tracking Near-Earth Objects (NEOs): Exploratory Data Analysis
#
# ## Data Collection:
# For this project, I obtained a dataset from NASA that provides detailed information about the NEOs and their approximate distance from Earth. The data is extracted via the NASA API for the month of January 2023. Due to the API's 7 days data fetch limit, the data is collected in 4 separate chunks, each corresponding to 7-day period in the month of January 2023. These chunks are then, merged to form a complete dataset for the entire month of January.
#
# Source: NASA Asteroids NeoWs (Near Earth Object Web Service)
# Time Period: January 2023

# %%
import requests  # Import the requests module to make HTTP requests
import json      # Import the json module to handle JSON data
# NASA API Key
api_key = '43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX'

# Function to make a request to the NASA API and fetch the data
def get_nasa_data(start_date, end_date, api_key):
    try:
        # Base URL for NASA's API
        base_url = "https://api.nasa.gov/neo/rest/v1/feed"
        # Make the GET request to the NASA API with the specified parameters (date range and API key)
        request = requests.get(base_url, params={'start_date': start_date, 'end_date': end_date, 'api_key': api_key})

        # Check if the request was successful (status code 200)
        if request.status_code == 200:
            # Print response to verify data
            print(f"Data fetched for {start_date} to {end_date}")
            return request.json()  # Return the data as JSON
        else:
            print(f"Failed to retrieve data for {start_date} to {end_date}, Status Code: {request.status_code}")
            return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
date_ranges = [
    ("2023-01-01", "2023-01-07"),
    ("2023-01-08", "2023-01-14"),
    ("2023-01-15", "2023-01-21"),
    ("2023-01-22", "2023-01-28")
]

# Initialize an empty list to hold the combined data
neo_data = []

# Loop through each date range, fetch the data and append it to the list
for start_date, end_date in date_ranges:
    data = get_nasa_data(start_date, end_date, api_key)
    if data:
        neo_data.append(data)  # Append data if fetched successfully
    else:
        print(f"No data for {start_date} to {end_date}")

# Check if neo_data is not empty and then print the first 5 entries 
if neo_data:
    print(json.dumps(neo_data[:1], indent=4))  # Print the combined data in a readable format
else:
    print("No data was retrieved for the given date ranges.")
# Out:
# Data fetched for 2023-01-01 to 2023-01-07
# Data fetched for 2023-01-08 to 2023-01-14
# Data fetched for 2023-01-15 to 2023-01-21
# Data fetched for 2023-01-22 to 2023-01-28
# [
#     {
#         "links": {
#             "next": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2023-01-07&end_date=2023-01-13&detailed=false&api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX",
#             "previous": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2022-12-26&end_date=2023-01-01&detailed=false&api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX",
#             "self": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2023-01-01&end_date=2023-01-07&detailed=false&api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#         },
#         "element_count": 115,
#         "near_earth_objects": {
#             "2023-01-01": [
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/2154347?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "2154347",
#                     "neo_reference_id": "2154347",
#                     "name": "154347 (2002 XK4)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2154347",
#                     "absolute_magnitude_h": 16.08,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 1.6164228334,
#                             "estimated_diameter_max": 3.6144313359
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 1616.4228333988,
#                             "estimated_diameter_max": 3614.4313358626
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 1.0043982724,
#                             "estimated_diameter_max": 2.2459028136
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 5303.2246887282,
#                             "estimated_diameter_max": 11858.3709039515
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 18:44",
#                             "epoch_date_close_approach": 1672598640000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "27.3921993676",
#                                 "kilometers_per_hour": "98611.9177232095",
#                                 "miles_per_hour": "61273.6107652909"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.3312263376",
#                                 "lunar": "128.8470453264",
#                                 "kilometers": "49550754.592860912",
#                                 "miles": "30789411.1800361056"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/2385186?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "2385186",
#                     "neo_reference_id": "2385186",
#                     "name": "385186 (1994 AW1)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2385186",
#                     "absolute_magnitude_h": 17.64,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.7880521833,
#                             "estimated_diameter_max": 1.7621382518
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 788.0521833356,
#                             "estimated_diameter_max": 1762.1382517555
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.4896727732,
#                             "estimated_diameter_max": 1.0949416076
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 2585.4731251747,
#                             "estimated_diameter_max": 5781.2936618894
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": true,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 19:45",
#                             "epoch_date_close_approach": 1672602300000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "12.9241938417",
#                                 "kilometers_per_hour": "46527.0978301312",
#                                 "miles_per_hour": "28910.1292045057"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.2232885314",
#                                 "lunar": "86.8592387146",
#                                 "kilometers": "33403488.692868118",
#                                 "miles": "20755965.4068433084"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/2453309?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "2453309",
#                     "neo_reference_id": "2453309",
#                     "name": "453309 (2008 VQ4)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2453309",
#                     "absolute_magnitude_h": 19.51,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.3330849243,
#                             "estimated_diameter_max": 0.744800533
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 333.0849242994,
#                             "estimated_diameter_max": 744.8005330139
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.2069693125,
#                             "estimated_diameter_max": 0.462797452
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 1092.7983430385,
#                             "estimated_diameter_max": 2443.5713807333
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 20:20",
#                             "epoch_date_close_approach": 1672604400000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "5.822172435",
#                                 "kilometers_per_hour": "20959.8207659374",
#                                 "miles_per_hour": "13023.6175198126"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.2644821197",
#                                 "lunar": "102.8835445633",
#                                 "kilometers": "39565961.760205039",
#                                 "miles": "24585148.6093019782"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3683468?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3683468",
#                     "neo_reference_id": "3683468",
#                     "name": "(2014 QR295)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3683468",
#                     "absolute_magnitude_h": 18.39,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.5578982211,
#                             "estimated_diameter_max": 1.2474983468
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 557.8982210671,
#                             "estimated_diameter_max": 1247.4983468323
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.3466617755,
#                             "estimated_diameter_max": 0.7751592953
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 1830.3747996059,
#                             "estimated_diameter_max": 4092.8424762213
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 13:38",
#                             "epoch_date_close_approach": 1672580280000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "16.1804693508",
#                                 "kilometers_per_hour": "58249.6896629513",
#                                 "miles_per_hour": "36194.0918908488"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.2629103243",
#                                 "lunar": "102.2721161527",
#                                 "kilometers": "39330824.516289241",
#                                 "miles": "24439041.1010278858"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3703782?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3703782",
#                     "neo_reference_id": "3703782",
#                     "name": "(2015 AE45)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3703782",
#                     "absolute_magnitude_h": 25.3,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0231502122,
#                             "estimated_diameter_max": 0.0517654482
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 23.150212221,
#                             "estimated_diameter_max": 51.7654482198
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0143848705,
#                             "estimated_diameter_max": 0.0321655483
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 75.9521422633,
#                             "estimated_diameter_max": 169.8341531374
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 00:59",
#                             "epoch_date_close_approach": 1672534740000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "6.8621510862",
#                                 "kilometers_per_hour": "24703.7439103688",
#                                 "miles_per_hour": "15349.9457647511"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.0569979859",
#                                 "lunar": "22.1722165151",
#                                 "kilometers": "8526777.284930033",
#                                 "miles": "5298293.7197111354"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3720918?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3720918",
#                     "neo_reference_id": "3720918",
#                     "name": "(2015 LJ)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3720918",
#                     "absolute_magnitude_h": 24.7,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0305179233,
#                             "estimated_diameter_max": 0.0682401509
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 30.5179232594,
#                             "estimated_diameter_max": 68.2401509401
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0189629525,
#                             "estimated_diameter_max": 0.0424024508
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 100.1244233463,
#                             "estimated_diameter_max": 223.8850168104
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 17:33",
#                             "epoch_date_close_approach": 1672594380000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "7.1892215518",
#                                 "kilometers_per_hour": "25881.1975863978",
#                                 "miles_per_hour": "16081.5696891703"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.4343374858",
#                                 "lunar": "168.9572819762",
#                                 "kilometers": "64975962.736835246",
#                                 "miles": "40374191.0685525548"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3767936?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3767936",
#                     "neo_reference_id": "3767936",
#                     "name": "(2017 BQ93)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3767936",
#                     "absolute_magnitude_h": 20.59,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.2025606009,
#                             "estimated_diameter_max": 0.4529392731
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 202.5606008648,
#                             "estimated_diameter_max": 452.9392730968
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.1258652831,
#                             "estimated_diameter_max": 0.2814433291
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 664.5689217411,
#                             "estimated_diameter_max": 1486.0212847469
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": true,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 09:38",
#                             "epoch_date_close_approach": 1672565880000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "24.1632170582",
#                                 "kilometers_per_hour": "86987.5814093681",
#                                 "miles_per_hour": "54050.7002373932"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.1028381402",
#                                 "lunar": "40.0040365378",
#                                 "kilometers": "15384366.728681374",
#                                 "miles": "9559402.2098320012"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3792438?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3792438",
#                     "neo_reference_id": "3792438",
#                     "name": "(2017 XY61)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3792438",
#                     "absolute_magnitude_h": 26.2,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0152951935,
#                             "estimated_diameter_max": 0.0342010925
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 15.2951935344,
#                             "estimated_diameter_max": 34.201092472
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0095039897,
#                             "estimated_diameter_max": 0.021251567
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 50.1810827555,
#                             "estimated_diameter_max": 112.2083122258
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 09:49",
#                             "epoch_date_close_approach": 1672566540000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "8.1685947474",
#                                 "kilometers_per_hour": "29406.9410907668",
#                                 "miles_per_hour": "18272.3295905378"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.1826363737",
#                                 "lunar": "71.0455493693",
#                                 "kilometers": "27322012.490044019",
#                                 "miles": "16977111.3222007022"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3824981?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3824981",
#                     "neo_reference_id": "3824981",
#                     "name": "(2018 KR)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3824981",
#                     "absolute_magnitude_h": 26.39,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0140137697,
#                             "estimated_diameter_max": 0.0313357417
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 14.0137697166,
#                             "estimated_diameter_max": 31.3357417074
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0087077501,
#                             "estimated_diameter_max": 0.0194711212
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 45.9769362371,
#                             "estimated_diameter_max": 102.8075548233
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 03:04",
#                             "epoch_date_close_approach": 1672542240000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "5.6111697795",
#                                 "kilometers_per_hour": "20200.2112060543",
#                                 "miles_per_hour": "12551.625679673"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.2228852462",
#                                 "lunar": "86.7023607718",
#                                 "kilometers": "33343158.085945594",
#                                 "miles": "20718477.7060294372"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3836251?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3836251",
#                     "neo_reference_id": "3836251",
#                     "name": "(2018 VB10)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3836251",
#                     "absolute_magnitude_h": 25.8,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0183888672,
#                             "estimated_diameter_max": 0.0411187571
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 18.388867207,
#                             "estimated_diameter_max": 41.1187571041
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0114263088,
#                             "estimated_diameter_max": 0.0255500032
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 60.3309310875,
#                             "estimated_diameter_max": 134.9040630575
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 22:31",
#                             "epoch_date_close_approach": 1672612260000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "6.2665160566",
#                                 "kilometers_per_hour": "22559.4578038017",
#                                 "miles_per_hour": "14017.5697670344"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.263842663",
#                                 "lunar": "102.634795907",
#                                 "kilometers": "39470300.39992781",
#                                 "miles": "24525707.396351378"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3837605?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3837605",
#                     "neo_reference_id": "3837605",
#                     "name": "(2019 AE3)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3837605",
#                     "absolute_magnitude_h": 27.4,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0088014652,
#                             "estimated_diameter_max": 0.0196806745
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 8.801465209,
#                             "estimated_diameter_max": 19.6806745089
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0054689752,
#                             "estimated_diameter_max": 0.0122290004
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 28.8761991163,
#                             "estimated_diameter_max": 64.5691441559
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 04:15",
#                             "epoch_date_close_approach": 1672546500000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "8.0072523281",
#                                 "kilometers_per_hour": "28826.1083810302",
#                                 "miles_per_hour": "17911.4227326462"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.1657976413",
#                                 "lunar": "64.4952824657",
#                                 "kilometers": "24802973.989504031",
#                                 "miles": "15411853.3799403878"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3959234?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3959234",
#                     "neo_reference_id": "3959234",
#                     "name": "(2019 YO4)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3959234",
#                     "absolute_magnitude_h": 21.89,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.1113153296,
#                             "estimated_diameter_max": 0.2489086439
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 111.3153296083,
#                             "estimated_diameter_max": 248.908643942
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0691681177,
#                             "estimated_diameter_max": 0.154664613
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 365.2077859922,
#                             "estimated_diameter_max": 816.6294353908
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 02:10",
#                             "epoch_date_close_approach": 1672539000000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "23.6789349299",
#                                 "kilometers_per_hour": "85244.1657476544",
#                                 "miles_per_hour": "52967.4095447023"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.4887677187",
#                                 "lunar": "190.1306425743",
#                                 "kilometers": "73118609.642279169",
#                                 "miles": "45433797.2385397722"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/3986848?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "3986848",
#                     "neo_reference_id": "3986848",
#                     "name": "(2020 BT3)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3986848",
#                     "absolute_magnitude_h": 25.56,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.02053785,
#                             "estimated_diameter_max": 0.0459240286
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 20.5378499518,
#                             "estimated_diameter_max": 45.924028604
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0127616244,
#                             "estimated_diameter_max": 0.0285358596
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 67.381399636,
#                             "estimated_diameter_max": 150.6693900052
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 10:47",
#                             "epoch_date_close_approach": 1672570020000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "10.3897506023",
#                                 "kilometers_per_hour": "37403.1021683567",
#                                 "miles_per_hour": "23240.8331223325"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.1125816303",
#                                 "lunar": "43.7942541867",
#                                 "kilometers": "16841972.094007461",
#                                 "miles": "10465116.1853305218"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54104550?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54104550",
#                     "neo_reference_id": "54104550",
#                     "name": "(2021 AP1)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54104550",
#                     "absolute_magnitude_h": 23.67,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0490405098,
#                             "estimated_diameter_max": 0.1096579137
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 49.0405098418,
#                             "estimated_diameter_max": 109.6579136575
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0304723506,
#                             "estimated_diameter_max": 0.0681382475
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 160.8940663093,
#                             "estimated_diameter_max": 359.770069444
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 16:46",
#                             "epoch_date_close_approach": 1672591560000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "9.6807800922",
#                                 "kilometers_per_hour": "34850.8083317651",
#                                 "miles_per_hour": "21654.9369881459"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.0721617969",
#                                 "lunar": "28.0709389941",
#                                 "kilometers": "10795251.111612603",
#                                 "miles": "6707857.9932478014"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54105994?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54105994",
#                     "neo_reference_id": "54105994",
#                     "name": "(2021 AX6)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54105994",
#                     "absolute_magnitude_h": 26.89,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.011131533,
#                             "estimated_diameter_max": 0.0248908644
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 11.1315329608,
#                             "estimated_diameter_max": 24.8908643942
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0069168118,
#                             "estimated_diameter_max": 0.0154664613
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 36.5207785992,
#                             "estimated_diameter_max": 81.6629435391
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 12:02",
#                             "epoch_date_close_approach": 1672574520000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "19.6174371846",
#                                 "kilometers_per_hour": "70622.7738645496",
#                                 "miles_per_hour": "43882.2452382253"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.3722367775",
#                                 "lunar": "144.8001064475",
#                                 "kilometers": "55685829.049663925",
#                                 "miles": "34601569.675355165"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": true,
#                     "sentry_data": "http://api.nasa.gov/neo/rest/v1/neo/sentry/54105994?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54166175?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54166175",
#                     "neo_reference_id": "54166175",
#                     "name": "(2021 NZ)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54166175",
#                     "absolute_magnitude_h": 23.8,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.046190746,
#                             "estimated_diameter_max": 0.1032856481
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 46.1907460282,
#                             "estimated_diameter_max": 103.2856480504
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0287015901,
#                             "estimated_diameter_max": 0.0641787064
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 151.544447199,
#                             "estimated_diameter_max": 338.8636855496
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 16:03",
#                             "epoch_date_close_approach": 1672588980000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "25.8568642683",
#                                 "kilometers_per_hour": "93084.7113659066",
#                                 "miles_per_hour": "57839.2196817768"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.4667250939",
#                                 "lunar": "181.5560615271",
#                                 "kilometers": "69821079.922989993",
#                                 "miles": "43384807.2839001834"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54202993?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54202993",
#                     "neo_reference_id": "54202993",
#                     "name": "(2021 TU1)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54202993",
#                     "absolute_magnitude_h": 22.54,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0825191939,
#                             "estimated_diameter_max": 0.1845185269
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 82.5191938525,
#                             "estimated_diameter_max": 184.5185269026
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.051275034,
#                             "estimated_diameter_max": 0.1146544616
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 270.7322719589,
#                             "estimated_diameter_max": 605.375763803
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 13:39",
#                             "epoch_date_close_approach": 1672580340000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "13.4011274156",
#                                 "kilometers_per_hour": "48244.0586963346",
#                                 "miles_per_hour": "29976.9819160641"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.093481207",
#                                 "lunar": "36.364189523",
#                                 "kilometers": "13984589.45222909",
#                                 "miles": "8689620.942537842"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54290862?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54290862",
#                     "neo_reference_id": "54290862",
#                     "name": "(2022 OS)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54290862",
#                     "absolute_magnitude_h": 21.77,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.1176399894,
#                             "estimated_diameter_max": 0.2630510131
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 117.639989374,
#                             "estimated_diameter_max": 263.0510131126
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0730980778,
#                             "estimated_diameter_max": 0.1634522711
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 385.9579827377,
#                             "estimated_diameter_max": 863.0282858603
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 12:50",
#                             "epoch_date_close_approach": 1672577400000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "24.2076057847",
#                                 "kilometers_per_hour": "87147.3808249178",
#                                 "miles_per_hour": "54149.9933797941"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.4498582792",
#                                 "lunar": "174.9948706088",
#                                 "kilometers": "67297840.370185304",
#                                 "miles": "41816938.9288090352"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54335607?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54335607",
#                     "neo_reference_id": "54335607",
#                     "name": "(2022 YR1)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54335607",
#                     "absolute_magnitude_h": 26.04,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0164647438,
#                             "estimated_diameter_max": 0.0368162863
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 16.4647437755,
#                             "estimated_diameter_max": 36.8162863142
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0102307143,
#                             "estimated_diameter_max": 0.0228765726
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 54.0181899685,
#                             "estimated_diameter_max": 120.7883447912
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-01",
#                             "close_approach_date_full": "2023-Jan-01 20:45",
#                             "epoch_date_close_approach": 1672605900000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "6.0346289386",
#                                 "kilometers_per_hour": "21724.6641790206",
#                                 "miles_per_hour": "13498.861472792"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.0417486541",
# ...
#                             "close_approach_date_full": "2023-Jan-07 21:09",
#                             "epoch_date_close_approach": 1673125740000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "13.5077525469",
#                                 "kilometers_per_hour": "48627.9091689858",
#                                 "miles_per_hour": "30215.4916722512"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.2227821309",
#                                 "lunar": "86.6622489201",
#                                 "kilometers": "33327732.256701183",
#                                 "miles": "20708892.5402070054"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54191845?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54191845",
#                     "neo_reference_id": "54191845",
#                     "name": "(2021 RH)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54191845",
#                     "absolute_magnitude_h": 25.78,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0185590173,
#                             "estimated_diameter_max": 0.0414992243
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 18.5590173004,
#                             "estimated_diameter_max": 41.4992242792
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0115320351,
#                             "estimated_diameter_max": 0.0257864145
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 60.8891663197,
#                             "estimated_diameter_max": 136.1523149843
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-07",
#                             "close_approach_date_full": "2023-Jan-07 14:13",
#                             "epoch_date_close_approach": 1673100780000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "13.5008037984",
#                                 "kilometers_per_hour": "48602.8936741507",
#                                 "miles_per_hour": "30199.9480165855"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.3549060651",
#                                 "lunar": "138.0584593239",
#                                 "kilometers": "53093191.389041337",
#                                 "miles": "32990579.3356589706"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54240297?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54240297",
#                     "neo_reference_id": "54240297",
#                     "name": "(2022 BB3)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54240297",
#                     "absolute_magnitude_h": 22.91,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0695913044,
#                             "estimated_diameter_max": 0.1556108872
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 69.5913043585,
#                             "estimated_diameter_max": 155.6108871884
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0432420184,
#                             "estimated_diameter_max": 0.0966920926
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 228.3179349914,
#                             "estimated_diameter_max": 510.5344231232
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-07",
#                             "close_approach_date_full": "2023-Jan-07 16:48",
#                             "epoch_date_close_approach": 1673110080000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "10.0943824875",
#                                 "kilometers_per_hour": "36339.7769549194",
#                                 "miles_per_hour": "22580.1241862386"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.3641430123",
#                                 "lunar": "141.6516317847",
#                                 "kilometers": "54475019.015463801",
#                                 "miles": "33849207.2076144138"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54290521?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54290521",
#                     "neo_reference_id": "54290521",
#                     "name": "(2022 OF)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54290521",
#                     "absolute_magnitude_h": 26.31,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0145396843,
#                             "estimated_diameter_max": 0.0325117225
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 14.5396842937,
#                             "estimated_diameter_max": 32.5117224521
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0090345382,
#                             "estimated_diameter_max": 0.0202018415
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 47.7023778182,
#                             "estimated_diameter_max": 106.6657594899
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-07",
#                             "close_approach_date_full": "2023-Jan-07 16:38",
#                             "epoch_date_close_approach": 1673109480000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "13.7642995208",
#                                 "kilometers_per_hour": "49551.4782747594",
#                                 "miles_per_hour": "30789.3615980026"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.1361616438",
#                                 "lunar": "52.9668794382",
#                                 "kilometers": "20369491.888178706",
#                                 "miles": "12657015.3457139028"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54336963?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54336963",
#                     "neo_reference_id": "54336963",
#                     "name": "(2022 YD6)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54336963",
#                     "absolute_magnitude_h": 24.18,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.038775283,
#                             "estimated_diameter_max": 0.0867041687
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 38.7752830381,
#                             "estimated_diameter_max": 86.70416872
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0240938364,
#                             "estimated_diameter_max": 0.053875456
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 127.2154996028,
#                             "estimated_diameter_max": 284.4625049034
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-07",
#                             "close_approach_date_full": "2023-Jan-07 23:10",
#                             "epoch_date_close_approach": 1673133000000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "9.5626087119",
#                                 "kilometers_per_hour": "34425.3913626959",
#                                 "miles_per_hour": "21390.5994275595"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.1030240883",
#                                 "lunar": "40.0763703487",
#                                 "kilometers": "15412184.168371921",
#                                 "miles": "9576687.1653416698"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54338283?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54338283",
#                     "neo_reference_id": "54338283",
#                     "name": "(2023 AF)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54338283",
#                     "absolute_magnitude_h": 20.66,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.1961349444,
#                             "estimated_diameter_max": 0.4385710684
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 196.1349443683,
#                             "estimated_diameter_max": 438.5710683707
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.1218725665,
#                             "estimated_diameter_max": 0.2725153433
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 643.4873708813,
#                             "estimated_diameter_max": 1438.8815039533
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-07",
#                             "close_approach_date_full": "2023-Jan-07 20:24",
#                             "epoch_date_close_approach": 1673123040000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "18.9482049659",
#                                 "kilometers_per_hour": "68213.5378772861",
#                                 "miles_per_hour": "42385.2396882503"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.4200441056",
#                                 "lunar": "163.3971570784",
#                                 "kilometers": "62837703.503815072",
#                                 "miles": "39045538.3915971136"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 },
#                 {
#                     "links": {
#                         "self": "http://api.nasa.gov/neo/rest/v1/neo/54338830?api_key=43CeF9mMNkbz8M1IhqOEYi3ici40QBdXXT2IXwMX"
#                     },
#                     "id": "54338830",
#                     "neo_reference_id": "54338830",
#                     "name": "(2023 AG1)",
#                     "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54338830",
#                     "absolute_magnitude_h": 22.66,
#                     "estimated_diameter": {
#                         "kilometers": {
#                             "estimated_diameter_min": 0.0780827277,
#                             "estimated_diameter_max": 0.1745982871
#                         },
#                         "meters": {
#                             "estimated_diameter_min": 78.0827277491,
#                             "estimated_diameter_max": 174.5982871157
#                         },
#                         "miles": {
#                             "estimated_diameter_min": 0.0485183426,
#                             "estimated_diameter_max": 0.1084903123
#                         },
#                         "feet": {
#                             "estimated_diameter_min": 256.1769365085,
#                             "estimated_diameter_max": 572.8290443006
#                         }
#                     },
#                     "is_potentially_hazardous_asteroid": false,
#                     "close_approach_data": [
#                         {
#                             "close_approach_date": "2023-01-07",
#                             "close_approach_date_full": "2023-Jan-07 12:29",
#                             "epoch_date_close_approach": 1673094540000,
#                             "relative_velocity": {
#                                 "kilometers_per_second": "12.9313991703",
#                                 "kilometers_per_hour": "46553.0370131045",
#                                 "miles_per_hour": "28926.2468040593"
#                             },
#                             "miss_distance": {
#                                 "astronomical": "0.2310035475",
#                                 "lunar": "89.8603799775",
#                                 "kilometers": "34557638.668443825",
#                                 "miles": "21473120.946721785"
#                             },
#                             "orbiting_body": "Earth"
#                         }
#                     ],
#                     "is_sentry_object": false
#                 }
#             ]
#         }
#     }
# ]
